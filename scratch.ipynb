# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import importlib, classes, gamestate, scoring, tests.test_scratch as test_scratch
importlib.reload(classes)
importlib.reload(gamestate)
importlib.reload(test_scratch)

deck, hands, card = test_scratch.main()
# Out:
# === Creating deck ===
# Deck size: 52
#
# === Shuffling deck ===
# The deck has been shuffled
# [XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX]
#
# === Dealing hands ===
#
# === Initial hands (all face down) ===
# Alice
# [     XX      XX      XX]
# [     XX      XX      XX]
# Bob
# [     XX      XX      XX]
# [     XX      XX      XX]
#
# === Reveal some cards for testing ===
# Alice
# [     2S      XX      XX]
# [     JS      XX      XX]
# Bob
# [     7D      XX      XX]
# [     4D      XX      XX]
#
# === Drawing from deck ===
# Drew: AH
# Deck now: [XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX, XX]

# %%
game = gamestate.GameState(["Alice", "Bob"])
# Out:
# The deck has been shuffled

# %%
game.hands
# Out:
# [Alice
#  [   0:XX    1:XX    2:XX]
#  [   3:XX    4:XX    5:XX],
#  Bob
#  [   0:XX    1:XX    2:XX]
#  [   3:XX    4:XX    5:XX]]

# %%
v = game.view()
print(v["phase"], v["deckCount"])
print(v["hands"][0]["playerName"], v["hands"][0]["visibleScore"])
print(v["validActions"])
# Out:
# setup 39
# Alice 0
# {'flip': [0, 1, 2, 3, 4, 5]}

# %%
for h in game.hands:
    print(h)
    print("partial score:", scoring.score_hand(h))  # face-down ignored by default
# Out:
# Aice
# [  0:8S   1:XX   2:XX]
# [  3:6S   4:XX   5:XX]
# partial score: 14
# Bob
# [  0:9D   1:XX   2:XX]
# [  3:7H   4:XX   5:XX]
# partial score: 16
# Carmen
# [  0:6C   1:XX   2:XX]
# [  3:KS   4:XX   5:XX]
# partial score: 6

# %%
for h in game.hands:
    h.reveal_all()
    print(h)
    print("final score:", scoring.score_hand(h))
# Out:
# Aice
# [  0:8S   1:2S   2:4S]
# [  3:6S   4:AD   5:QC]
# final score: 27
# Bob
# [  0:9D   1:7C   2:AH]
# [  3:7H   4:8D   5:6H]
# final score: 38
# Carmen
# [  0:6C   1:5H   2:9C]
# [  3:KS   4:AC   5:2D]
# final score: 19

# %%
game.hands[0].show()
# Out:
# Aice: 2D XX XX 10D XX XX
